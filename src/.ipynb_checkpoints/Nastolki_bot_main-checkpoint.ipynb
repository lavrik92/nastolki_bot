# %%
import os
from dotenv import load_dotenv
from pathlib import Path
import logging
import json
from aiogram import Bot, Dispatcher
from aiogram.fsm.storage.memory import MemoryStorage
from routers.main_router import main_router
from routers.show_games_router import show_games_router
from routers.callback_router import callback_router
from routers.insert_game_router import insert_game_router
from routers.voting_router import voting_router, user_votes
from routers.game_selection_router import games_selection_router, game_collection
from keyboards.keyboards import GameKeyboards
from states.fsm_states import GameSelection2
from services.game_sevice import GameService

# %%
# Находим корень проекта
project_root = GameService.find_project_root()
env_path = project_root / '.env'

# Загружаем .env
if env_path.exists():
    load_dotenv(dotenv_path=env_path)
    #print(f"Загружен .env из: {env_path}")
else:
    print(f"Файл .env не найден в {project_root}")
    # Можно загрузить без пути - будет искать автоматически
    load_dotenv()

# Получаем токен
BOT_TOKEN = os.getenv('BOT_TOKEN')
# Получаем айдишники меня и Кусоча
admin_ids_str = os.getenv('ADMIN_IDS', '')

if admin_ids_str:
    admin_ids = list(map(int, admin_ids_str.split(',')))
else:
    admin_ids = []

# Настройка логирования
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger("name.log")

# %%
# --- Запуск бота ---
async def main():
    """Точка входа."""
    bot = Bot(token=BOT_TOKEN)
    dp = Dispatcher(storage=MemoryStorage())
    
    # Подключаем роутеры
    dp.include_router(main_router)
    dp.include_router(show_games_router)
    dp.include_router(games_selection_router)
    dp.include_router(voting_router)
    dp.include_router(insert_game_router)
    dp.include_router(callback_router)
    
    dp.startup.register(GameKeyboards.set_main_menu)
    
    logger.info("Бот запущен...")
    try:
        await dp.start_polling(bot)
    finally:
        await bot.session.close()

if __name__ == "__main__":
    await main()
# Out:
# 2026-03-13 13:46:27,430 - name.log - INFO - Бот запущен...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 24
#      21         await bot.session.close()
#      23 if __name__ == "__main__":
# ---> 24     await main()
#
# Cell In[3], line 19, in main()
#      17 logger.info("Бот запущен...")
#      18 try:
# ---> 19     await dp.start_polling(bot)
#      20 finally:
#      21     await bot.session.close()
#
# File C:\Users\CuSO4\miniconda3\Lib\site-packages\aiogram\dispatcher\dispatcher.py:595, in Dispatcher.start_polling(self, polling_timeout, handle_as_tasks, backoff_config, allowed_updates, handle_signals, close_bot_session, tasks_concurrency_limit, *bots, **kwargs)
#     592 if "bot" in workflow_data:
#     593     workflow_data.pop("bot")
# --> 595 await self.emit_startup(bot=bots[-1], **workflow_data)
#     596 loggers.dispatcher.info("Start polling")
#     597 try:
#
# File C:\Users\CuSO4\miniconda3\Lib\site-packages\aiogram\dispatcher\router.py:279, in Router.emit_startup(self, *args, **kwargs)
#     271 """
#     272 Recursively call startup callbacks
#     273
#    (...)    276 :return:
#     277 """
#     278 kwargs.update(router=self)
# --> 279 await self.startup.trigger(*args, **kwargs)
#     280 for router in self.sub_routers:
#     281     await router.emit_startup(*args, **kwargs)
#
# File C:\Users\CuSO4\miniconda3\Lib\site-packages\aiogram\dispatcher\event\event.py:43, in EventObserver.trigger(self, *args, **kwargs)
#      38 """
#      39 Propagate event to handlers.
#      40 Handler will be called when all its filters is pass.
#      41 """
#      42 for handler in self.handlers:
# ---> 43     await handler.call(*args, **kwargs)
#
# File C:\Users\CuSO4\miniconda3\Lib\site-packages\aiogram\dispatcher\event\handler.py:69, in CallableObject.call(self, *args, **kwargs)
#      68 async def call(self, *args: Any, **kwargs: Any) -> Any:
# ---> 69     wrapped = partial(self.callback, *args, **self._prepare_kwargs(kwargs))
#      70     if self.awaitable:
#      71         return await wrapped()
#
# TypeError: the first argument must be callable
